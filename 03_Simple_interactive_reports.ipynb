# %%
from IPython.core.display import HTML, Image, display
custom_style_file = 'styles/ricardo_stylesheet.css' # or the path to the style sheet
styles = open(custom_style_file, 'r').read()
HTML(styles)
# Out:
# <style>
# /* Version last updated: 19 June 2019 */
#
#
# /* Dummies added as it does not seem to render the first one */
# h1, h2, h3, h4, h5, h6, body, p, div, table, th, td, thead, caption, article, figcaption, footer, footnote {}
#
#
# /* Headings */
# h1, h2, h3, h4 {
#     font-family: Arial, "Helvetica Neue", Helvetica, sans-serif !important;
#     padding-top: 3pt;
#     padding-bottom: 3pt;
#     text-align: left;
#     color: #0070C0 !important;
# }
#
# h1 {font-size: 20pt; text-align: center}
# h2 {font-size: 20pt;}
# h3 {font-size: 16pt;}
# h4 {font-size: 12pt;}
#
# /* Chapter numbering - remove if using TOC */
# /* Need to reset all counters at the same time if using the same element */
# /* body {counter-reset: h2 0 tables 0 figures 0}
# h2 {counter-reset: h3 0}
# h3 {counter-reset: h4 0}
# h4 {counter-reset: h5 0}
# h5 {counter-reset: h6 0}
#
# h2:before {counter-increment: h2; content: counter(h2) ". "}
# h3:before {counter-increment: h3; content: counter(h2) "." counter(h3) ". "}
# h4:before {counter-increment: h4; content: counter(h2) "." counter(h3) "." counter(h4) ". "}
# h5:before {counter-increment: h5; content: counter(h2) "." counter(h3) "." counter(h4) "." counter(h5) ". "}
# h6:before {counter-increment: h6; content: counter(h2) "." counter(h3) "." counter(h4) "." counter(h5) "." counter(h6) ". "}
# */
#
# body {counter-reset: tables 0 figures 0}
#
#
# /* Body text */
# p, body {
#     font-family: Arial, "Helvetica Neue", Helvetica, sans-serif;
#     font-size: 11pt;
#     color: black;
# }
#
# /* Tables */
# table, th, td {border: 1px solid black;}
# table { border-collapse: collapse;}
# thead {background-color: #0070C0; color: white;}
#
# .rendered_html table, .rendered_html td, .rendered_html th {
#     border: 1px solid black !important;
# }
#
#
# /* Captions */
# caption, figcaption {
#     color: black !important;
#     font-size: 10pt;
#     font-weight: bold;
#     text-align: left;
# }
#
# caption:before {counter-increment: tables; content: "Table " counter(tables) ". "}
# figcaption:before {counter-increment: figures; content: "Figure " counter(figures) ". "}
#
# /* Comments */
# div.todo {
#     background-color: #fcf2f2;
#     border-color: #dFb5b4;
#     border-left: 5px solid #dfb5b4;
#     padding: 0.5em;
#     }
#
# div.commenter1 {
#     background-color: lemonchiffon;
#     border-color: black;
#     border-left: 5px solid gold;
#     padding: 0.5em;
#     }
#
# div.commenter2 {
#     background-color: lightcyan;
#     border-color: black;
#     border-left: 5px solid cyan;
#     padding: 0.5em;
#     }
#
# div.commenter3 {
#     background-color: lavender;
#     border-color: black;
#     border-left: 5px solid blueviolet;
#     padding: 0.5em;
#     }
#
# /* Footer */
# div.footnote {
#     font-size: 10pt;
#     font-style: italic;
#     color: DarkGray;
#     text-align: right;
#
# }
#
# </style>

# %%
Image(filename = 'styles/ricardo_logo.png', width = 80, embed = True)

# %% [markdown]
# <hr>
#
# # Introduction to creating dashboards with notebooks

# %%
display(HTML('''<div class = "todo"> 
    <b>Before you start, check that you have the latest version of this guidance:</b> <br>
    Go to the GitHub repository: <a href https://github.com/genagibson/ricardo_template_style> https://github.com/genagibson/ricardo_template_style </a> <br>
    Right click on '03_Simple_dashboards.html', select `save link as` and view in your browser, since GitHub will not render the html <br>
</div>'''))
# Out:
# <div class = "todo">
#     <b>Before you start, check that you have the latest version of this guidance:</b> <br>
#     Go to the GitHub repository: <a href https://github.com/genagibson/ricardo_template_style> https://github.com/genagibson/ricardo_template_style </a> <br>
#     Right click on '03_Simple_dashboards.html', select `save link as` and view in your browser, since GitHub will not render the html <br>
# </div>

# %% [markdown]
# ## Intro
#
# The `Plotly` library is a great way of creating interactive reports within Jupyter Notebooks.
#
# If you haven't followed the previous tutorials on setting up your notebooks, find them here: https://github.com/genagibson/ricardo_template_style

# %%
display(HTML('''<div class = "commenter1"> 
    <b>Good practice:</b> Quality checks are important for any kind of deliverable, including code. <br>
    Please make sure you're getting your code reviewed and link up with the data science team for best practices. 
</div>'''))
# Out:
# <div class = "commenter1">
#     <b>Good practice:</b> Quality checks are important for any kind of deliverable, including code. <br>
#     Please make sure you're getting your code reviewed and link up with the data science team for best practices.
# </div>

# %% [markdown]
# ## Set up
#
# The basic libraries you will need to include interactive reporting are included in the import statements below. As ever, if you are missing a library you can install it with pip.

# %%
import os

# Numerical python
import numpy as np
import pandas as pd

# iPython display
from IPython.core.display import HTML, Image, display

# Static plotting
import matplotlib.pyplot as plt
# %matplotlib inline 
plt.style.use('seaborn-white')

import seaborn as sns

# Interactive plotting
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.offline import iplot, init_notebook_mode, offline
init_notebook_mode(connected=True)

# Other helpful functions
import itertools
import warnings
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# ### Other libraries
#
# We can use notebooks to create simple report-like dashboards. The layouts are somewhat restricted by the linear display of the cells, and there doesn't seem to be a way around this at the time of writing.
#
# A number of options are available to create dashboards, but at this point in time, most of them cannot be exported to html (although this may change in time). The options that cannot be exported include:
# * Dash
# * ipywidgets and figure widgets
# * Dashboard extension to jupyter
#
# Deploying to a server is much more complicated, and any external-facing website would require involvement from our digital services team, adding significantly to the cost and time taken.
#
# Instead, it is recommended to keep within the notebook format. In most cases this should be sufficient, but it is important to ensure that the proposal does not over-promise.
#
# ### Import data
#
# Let's start with a built-in dataset.

# %%
df = sns.load_dataset('iris')
df.head().style.set_caption('Example data from the iris dataframe')
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_b9169da4_93ec_11e9_b726_acde48001122" ><caption>Example data from the iris dataframe</caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >sepal_length</th>
#         <th class="col_heading level0 col1" >sepal_width</th>
#         <th class="col_heading level0 col2" >petal_length</th>
#         <th class="col_heading level0 col3" >petal_width</th>
#         <th class="col_heading level0 col4" >species</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_b9169da4_93ec_11e9_b726_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_b9169da4_93ec_11e9_b726_acde48001122row0_col0" class="data row0 col0" >5.1</td>
#         <td id="T_b9169da4_93ec_11e9_b726_acde48001122row0_col1" class="data row0 col1" >3.5</td>
#         <td id="T_b9169da4_93ec_11e9_b726_acde48001122row0_col2" class="data row0 col2" >1.4</td>
#         <td id="T_b9169da4_93ec_11e9_b726_acde48001122row0_col3" class="data row0 col3" >0.2</td>
#         <td id="T_b9169da4_93ec_11e9_b726_acde48001122row0_col4" class="data row0 col4" >setosa</td>
#     </tr>    <tr>
#         <th id="T_b9169da4_93ec_11e9_b726_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_b9169da4_93ec_11e9_b726_acde48001122row1_col0" class="data row1 col0" >4.9</td>
#         <td id="T_b9169da4_93ec_11e9_b726_acde48001122row1_col1" class="data row1 col1" >3</td>
#         <td id="T_b9169da4_93ec_11e9_b726_acde48001122row1_col2" class="data row1 col2" >1.4</td>
#         <td id="T_b9169da4_93ec_11e9_b726_acde48001122row1_col3" class="data row1 col3" >0.2</td>
#         <td id="T_b9169da4_93ec_11e9_b726_acde48001122row1_col4" class="data row1 col4" >setosa</td>
#     </tr>    <tr>
#         <th id="T_b9169da4_93ec_11e9_b726_acde48001122level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_b9169da4_93ec_11e9_b726_acde48001122row2_col0" class="data row2 col0" >4.7</td>
#         <td id="T_b9169da4_93ec_11e9_b726_acde48001122row2_col1" class="data row2 col1" >3.2</td>
#         <td id="T_b9169da4_93ec_11e9_b726_acde48001122row2_col2" class="data row2 col2" >1.3</td>
#         <td id="T_b9169da4_93ec_11e9_b726_acde48001122row2_col3" class="data row2 col3" >0.2</td>
#         <td id="T_b9169da4_93ec_11e9_b726_acde48001122row2_col4" class="data row2 col4" >setosa</td>
#     </tr>    <tr>
#         <th id="T_b9169da4_93ec_11e9_b726_acde48001122level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_b9169da4_93ec_11e9_b726_acde48001122row3_col0" class="data row3 col0" >4.6</td>
#         <td id="T_b9169da4_93ec_11e9_b726_acde48001122row3_col1" class="data row3 col1" >3.1</td>
#         <td id="T_b9169da4_93ec_11e9_b726_acde48001122row3_col2" class="data row3 col2" >1.5</td>
#         <td id="T_b9169da4_93ec_11e9_b726_acde48001122row3_col3" class="data row3 col3" >0.2</td>
#         <td id="T_b9169da4_93ec_11e9_b726_acde48001122row3_col4" class="data row3 col4" >setosa</td>
#     </tr>    <tr>
#         <th id="T_b9169da4_93ec_11e9_b726_acde48001122level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_b9169da4_93ec_11e9_b726_acde48001122row4_col0" class="data row4 col0" >5</td>
#         <td id="T_b9169da4_93ec_11e9_b726_acde48001122row4_col1" class="data row4 col1" >3.6</td>
#         <td id="T_b9169da4_93ec_11e9_b726_acde48001122row4_col2" class="data row4 col2" >1.4</td>
#         <td id="T_b9169da4_93ec_11e9_b726_acde48001122row4_col3" class="data row4 col3" >0.2</td>
#         <td id="T_b9169da4_93ec_11e9_b726_acde48001122row4_col4" class="data row4 col4" >setosa</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# ## Plotting overview
#
# ### Simple plot

# %% [markdown]
# We have our simple graph that comes with standard Plotly interactivity: zoom, pan, select etc.

# %%
# Universal settings
marker_size = 10
opacity = 0.5

# %%
x = df['sepal_length']
y = df['sepal_width']

display(HTML('<figcaption> Plotly graph </figcaption>'))

trace = go.Scatter(
    mode = 'markers',
    x = list(x),
    y = list(y),
    marker = dict(size = marker_size, 
                 opacity = opacity)
)

data = [trace]
layout = go.Layout(
    xaxis = dict(title = 'sepal_length'),
    yaxis = dict(title = 'sepal_width')
)

fig = dict(data = data,
             layout = layout);
plotly.offline.iplot(fig);
# Out:
# <figcaption> Plotly graph </figcaption>
# <div id="7ddfcb1c-1b47-4df7-9b73-4cc9b3976968" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("
}}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("7ddfcb1c-1b47-4df7-9b73-4cc9b3976968"));});</script>

# %% [markdown]
# This works, but it's a pretty manual process. For use in any serious report, we'll need to improve it.

# %%
display(HTML('''<div class = "commenter1"> 
    <b>Good practice:</b> The whole point of doing things in Python is to reduce the amount of repetitive work. <br>
    If you find yourself typing something manually more than once, it's time to create a function.
</div>'''))
# Out:
# <div class = "commenter1">
#     <b>Good practice:</b> The whole point of doing things in Python is to reduce the amount of repetitive work. <br>
#     If you find yourself typing something manually more than once, it's time to create a function.
# </div>

# %% [markdown]
# ## Using loops for easier graphing
#
# First, let's make a custom function that creates a graph of any two variables. This is already an improvement when we're trying to create a lot of graphs...
#
# The function below is based on the manually-typed way of creating a plot, but it can be changed by editing the input variables to use for x and y.

# %%
def plot_any(x, y, mode = 'markers'):
    ''' This function creates a plotly figure object for a given x and y 
    Params:
        x: parameter to be plotted on the x axis
        y: parameter to be plotted on the y axis
        mode: optional setting to change the type of chart
        
    Returns:
        fig object that can be plotted directly or saved
    
    '''
    # Updates the x and y traces according to the input
    trace = go.Scatter(
        mode = mode,
        x = list(df[x]),
        y = list(df[y]),
        marker = dict(size = marker_size, 
                     opacity = opacity)
    )

    data = [trace]
    layout = go.Layout(
        xaxis = dict(title = str(x)),
        yaxis = dict(title = str(y))
    )

    fig = dict(data = data,
                 layout = layout);
    return fig # Saves to a fig variable, but does not plot it yet

# %%
display(HTML('''<div class = "commenter1"> 
    <b>Good practice:</b> it's important to include docstrings for every function you create. 
    This is the text included in triple quotes at the start of the function. <br>
    The first line gives a short explanation of the function <br>
    "Params" lists the input parameters <br>
    "Returns" lists what the function returns
</div>'''))
# Out:
# <div class = "commenter1">
#     <b>Good practice:</b> it's important to include docstrings for every function you create.
#     This is the text included in triple quotes at the start of the function. <br>
#     The first line gives a short explanation of the function <br>
#     "Params" lists the input parameters <br>
#     "Returns" lists what the function returns
# </div>

# %% [markdown]
# Why am I going to insist that you include docstrings? So many reasons! But mainly it helps to understand what you meant the function to do so that bugs can be spotted. It's also super useful when you're reusing the function later on... type in the function name and hit tab, and you'll see a helpful reminder of what the inputs and outputs should be.

# %%
display(HTML('<figcaption> Press shift + tab to see the docstring </figcaption>'))
Image(filename = 'files/pictures/docstrings.PNG', width = 700, embed = True)
# Out:
# <figcaption> Press shift + tab to see the docstring </figcaption>

# %% [markdown]
# Let's test out the new function.

# %%
# Choose any x and y
x = 'petal_length'
y = 'petal_width'

# %%
fig = plot_any(x, y)
display(HTML('<figcaption> Plotly graph </figcaption>'))
plotly.offline.iplot(fig);
# Out:
# <figcaption> Plotly graph </figcaption>
# <div id="4ce34374-cd36-4ebf-9321-a209798c01ec" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("
}}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("4ce34374-cd36-4ebf-9321-a209798c01ec"));});</script>

# %% [markdown]
# Great - we can create any graph in this format with just 3 lines of code. The `markers` argument is optional, and will default to a scatter plot if we just leave it out, as done here.

# %% [markdown]
# ### Create traces using a loop
#
# When we want to have interactive plotting on the graph, the traces need to be loaded up in advance.
# We can edit the function to plot the traces that we want, and store them in a list.

# %%
# We can get a list of the unique values of any column using unique()
subset_list = df['species'].unique()
subset_list
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
def make_traces_by_category(x, y, categorical_column, mode = 'markers'):
    ''' Makes a list of traces, one for each category in the categorical column
    Params:
        x: parameter to be plotted on the x axis
        y: parameter to be plotted on the y axis
        categorical_column: categories to be shown in different colours
        mode: optional setting to change the type of chart
        
    Returns:
        trace_list: list of traces to be incorporated into a graph object, subsetted by category
    '''
    trace_list = []
    
    # Create a list of the unique values
    subset_list = df[categorical_column].unique()
    
    # Get the trace for the subset
    for each in subset_list:
        trace = go.Scatter(
            mode = mode,
            x = list(df.loc[df[categorical_column] == each][x]), # Subsets the dataframe by the category
            y = list(df.loc[df[categorical_column] == each][y]),
            
            marker = dict(size = marker_size, 
                         opacity = opacity),
            name = str(each) # Assigns a name to each trace for use in the legend
        )
        
        trace_list.append(trace)
    
    return trace_list

# %% [markdown]
# Let's apply `make_traces_by_category` to the iris dataset, using species as the categorical column. We can see that the length of `trace_list` is 3: one for each species.
#
# You can customise the traces a lot yourself - this version uses the defaults for most settings.

# %%
trace_list = make_traces_by_category(x, y, 'species')
len(trace_list)
# Out:
# 3

# %% [markdown]
# ### Putting it all together
#
# Now let's put it all together into a single function that plots everything for us in one go.
# We can even go further and get the function to print the graph out for us by default.

# %%
def plot_categorical(x, y, categorical_column, mode = 'markers', 
                     print_graph = True, 
                     title = 'Please update title'):
    ''' Makes a figure with interactive selection of different categories
    Params:
        x: parameter to be plotted on the x axis
        y: parameter to be plotted on the y axis
        categorical_column: categories to be shown in different colours
        mode: optional setting to change the type of chart
        print_graph: boolean option to print graph or just return figure
        title: string - title to give the graph
        
    Returns:
        fig: graph object
    '''
    layout = go.Layout(
        xaxis = dict(title = x),
        yaxis = dict(title = y)
    )

    trace_list = make_traces_by_category(x, y, categorical_column) # Calls the make_traces function within this wrapper
    fig = dict(data = trace_list,
              layout = layout);
    # Optional printing
    if print_graph == True:
        title_display = '<figcaption>'+ str(title)+'</figcaption>'
        display(HTML(title_display))
        plotly.offline.iplot(fig);
        
    return fig

# %% [markdown]
# It's now possible to create a graph with caption in a single line. This version allows us select the different categories of species by clicking the legend to turn them on and off.
#
# You'll find that the graphs quickly become cluttered if you leave the `hoverinfo` parameters as their defaults, so this will probably be something you customise early on.

# %%
fig = plot_categorical(x, y, 'species', title = 'Graph with option to select and de-select categories')
# Out:
# <figcaption>Graph with option to select and de-select categories</figcaption>
# <div id="409dd06c-6e46-4058-a306-2ebde5e7bd6b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot
.1, 1.8, 2.2, 2.1, 1.7, 1.8, 1.8, 2.5, 2.0, 1.9, 2.1, 2.0, 2.4, 2.3, 1.8, 2.2, 2.3, 1.5, 2.3, 2.0, 2.0, 1.8, 2.1, 1.8, 1.8, 1.8, 2.1, 1.6, 1.9, 2.0, 2.2, 1.5, 1.4, 2.3, 2.4, 1.8, 1.8, 2.1, 2.4, 2.3, 1.9, 2.3, 2.5, 2.3, 1.9, 2.0, 2.3, 1.8], "type": "scatter", "uid": "fbe8da09-788c-4f8d-8606-970446e2ecc7"}], {"xaxis": {"title": {"text": "petal_length"}}, "yaxis": {"title": {"text": "petal_width"}}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("409dd06c-6e46-4058-a306-2ebde5e7bd6b"));});</script>

# %% [markdown]
# And we can easily change the chart by editing the values of x and y. Let's change them to `sepal_length` and `sepal_width` below.

# %%
fig = plot_categorical('sepal_length', 'sepal_width', 'species', title = 'Graph with option to select and de-select categories')
# Out:
# <figcaption>Graph with option to select and de-select categories</figcaption>
# <div id="6946e692-91ba-4892-bcd4-4494751f415e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("6946e692-91ba-4892-bcd4-4494751f415e", [{"marker": {"opacity": 0.5, "size": 10}, "mode": "markers", "name": "setosa", "x": [5.1, 4.9, 4.7, 4.6, 5.0, 5.4, 4.6, 5.0, 4.4, 4.9, 5.4, 4.8, 4.8, 4.3, 5.8, 5.7, 5.4, 5.1, 5.7, 5.1, 5.4, 5.1, 4.6, 5.1, 4.8, 5.0, 5.0, 5.2, 5.2, 4.7, 4.8, 5.4, 5.2, 5.5, 4.9, 5.0, 5.5, 4.9, 4.4, 5.1, 5.0, 4.5, 4.4, 5.0, 5.1, 4.8, 5.1, 4.6, 5.3, 5.0], "y": [3.5, 3.0, 3.2, 3.1, 3.6, 3.9, 3.4, 3.4, 2.9, 3.1, 3.7, 3.4, 3.0, 3.0, 4.0, 4.4, 3.9, 3.5, 3.8, 3.8, 3.4, 3.7, 3.6, 3.3, 3.4, 3.0, 3.4, 3.5, 3.4, 3.2, 3.1, 3.4, 4.1, 4.2, 3.1, 3.2, 3.5, 3.6, 3.0, 3.4, 3.5, 2.3, 3.2, 3.5, 3.8, 3.0, 3.8, 3.2, 3.7, 3.3], "type": "scatter", "uid": "cd137ca7-b33b-40e9-890b-d8e220540cf9"}, {"marker": {"opacity": 0.5, "size": 10}, "mode": "markers", "name": "versicolor", "x": [7.0, 6.4, 6.9, 5.5, 6.5, 5.7, 6.3, 4.9, 6.6, 5.2, 5.0, 5.9, 6.0, 6.1, 5.6, 6.7, 5.6, 5.8, 6.2, 5.6, 5.9, 6.1, 6.3, 6.1, 6.4, 6.6, 6.8, 6.7, 6.0, 5.7, 5.5, 5.5, 5.8, 6.0, 5.4, 6.0, 6.7, 6.3, 5.6, 5.5, 5.5, 6.1, 5.8, 5.0, 5.6, 5.7, 5.7, 6.2, 5.1, 5.7], "y": [3.2, 3.2, 3.1, 2.3, 2.8, 2.8, 3.3, 2.4, 2.9, 2.7, 2.0, 3.0, 2.2, 2.9, 2.9, 3.1, 3.0, 2.7, 2.2, 2.5, 3.2, 2.8, 2.5, 2.8, 2.9, 3.0, 2.8, 3.0, 2.9, 2.6, 2.4, 2.4, 2.7, 2.7, 3.0, 3.4, 3.1, 2.3, 3.0, 2.5, 2.6, 3.0, 2.6, 2.3, 2.7, 3.0, 2.9, 2.9, 2.5, 2.8], "type": "scatter", "uid": "b903504c-5bb6-4911-94f7-70d7e0d7ac23"}, {"marker": {"opacity": 0.5, "size": 10}, "mode": "markers", "name": "virginica", "x": [6.3, 5.8, 7.1, 6.3, 6.5, 7.6, 4.9, 7.3, 6.7, 7.2, 6.5, 6.4, 6.8, 5.7, 5.8, 6.4, 6.5, 7.7, 7.7, 6.0, 6.9, 5.6, 7.7, 6.3, 6.7, 7.2, 6.2, 6.1, 6.4, 7.2, 7.4, 7.9, 6.4, 6.3, 6.1, 7.7, 6.3, 6.4, 6.0, 6.9, 6.7, 6.9, 5.8, 6.8, 6.7, 6.7, 6.3, 6.5, 6.2, 5.9], "y": [3.3, 2.7, 3.0, 2.9, 3.0, 3.0, 2.5, 2.9, 2.5, 3.6, 3.2, 2.7, 3.0, 2.5, 2.8, 3.2, 3.0, 3.8, 2.6, 2.2, 3.2, 2.8, 2.8, 2.7, 3.3, 3.2, 2.8, 3.0, 2.8, 3.0, 2.8, 3.8, 2.8, 2.8, 2.6, 3.0, 3.4, 3.1, 3.0, 3.1, 3.1, 3.1, 2.7, 3.2, 3.3, 3.0, 2.5, 3.0, 3.4, 3.0], "type": "scatter", "uid": "b3f9f379-5991-467a-85e2-012935e8af2d"}], {"xaxis": {"title": {"text": "sepal_length"}}, "yaxis": {"title": {"text": "sepal_width"}}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("6946e692-91ba-4892-bcd4-4494751f415e"));});</script>

# %% [markdown]
# ## Controlling charts using toggle buttons
#
# Buttons can be used to update both chart layouts and data attributes.
#
# ### Automate the generation of the buttons
# The information for the toggle buttons is contained in a dictionary. In this case we will toggle visibility for the difference traces in order to update the charts. This is done by using the `truth` list for each button.

# %%
def make_buttons(variable_list):
    ''' Generates the button dictionaries needed for Plotly graph objects 
    Params:
        variable_list: list of the variables you want to create toggle buttons for
    
    Returns:
        button_list: list of button dictionaries
    '''
    button_list = []   
    
    # Create buttons
    for index, item in enumerate(variable_list):
        # Initialise blank dictionary
        button_dict = {}
        button_dict['label'] = str(item) # Label for the button
        button_dict['method'] = 'update' # Assign the update method 
        
        # Initialise visibility a list
        truth = [False]*len(variable_list)
        truth[index] = True # This changes one element of the list to True, in order to show the right trace
        button_dict['args'] = [
            {'visible': truth},
            {'yaxis': dict(title = str(item))} # Update y axis label to match what is showing
                              ]
        
        button_list.append(button_dict)
    return button_list

# %% [markdown]
# We can see the difference between the two buttons is in the labels, as well as the position of 'True' in the 'visible' list.

# %%
# Create a list of the numerical variables in the dataset (excluding species)
variable_list = list(df)[:4] 
variable_list
# Out:
# ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']

# %%
button_list = make_buttons(variable_list)

# Let's look at the first button
button_list[0]
# Out:
# {'label': 'sepal_length',
#  'method': 'update',
#  'args': [{'visible': [True, False, False, False]},
#   {'yaxis': {'title': 'sepal_length'}}]}

# %%
# And the second
button_list[1]
# Out:
# {'label': 'sepal_width',
#  'method': 'update',
#  'args': [{'visible': [False, True, False, False]},
#   {'yaxis': {'title': 'sepal_width'}}]}

# %% [markdown]
# ### Using buttons to update the charts
#
# Let's simplify the graph and get rid of the different colours by category. We still want a loop to generate the traces for us - example code is in the make_simple_traces function.

# %%
def make_simple_traces(x, y_list, mode = 'markers'):
    ''' Makes a list of traces for a plotly graph object
    
    Params:
        x: parameter to be plotted on the x axis
        y_list: list of parameters to be plotted on the y axis
        mode: optional setting to change the type of chart
        
    Returns:
        trace_list for incorporation into figures, without subsetting by category
    '''
    trace_list = []
    
    # Get the traces (we are no longer subsetting by category)
    for index, item in enumerate(y_list):
        # Set default visibility to be true for the first trace
        if index == 0:
                visible = True
        else:
            visible = False
            
        # Create traces
        trace = go.Scatter(
            mode = mode,
            x = list(df[x]), # Static x
            y = list(df[item]), # Changes for each value of y_list
            
            marker = dict(size = marker_size, 
                         opacity = opacity),
            name = str(item),
            visible = visible # if else can't be used with go.Scatter, so these need to be done first and assigned here
        )
        
        trace_list.append(trace)
    
    return trace_list

# %% [markdown]
# We could then create a wrapper that uses this as a building block to generate a graph, and following all of the good practices mentioned above.

# %%
def make_toggle_plot(x, y_list,
                     print_graph = True, 
                     title = 'Please update title'):
    ''' Creates a Plotly figure with toggle buttons that change the variable plotted on the y axis
    
    Params: 
        x: parameter to be plotted on the x axis
        y_list: list of the y parameters to show
        print_graph: boolean option to print graph or just return figure
        title: string - title to give the graph
        
    Returns:
        fig: graph object
    '''
    
    trace_list = make_simple_traces(x, y_list)  # calls the function defined above

    # This allows us to the buttons to the graph and indicates that we want them to update the data display
    updatemenus = list([
        dict(type = 'buttons', 
             active = 1,
            buttons = button_list)

    ])

    layout = go.Layout(
        xaxis = dict(title = str(x)), # Let's keep the x variable fixed
        showlegend = False, # Remove legend
        updatemenus = updatemenus
    )

    fig = dict(data = trace_list,
              layout = layout);
    
    # Optional printing
    if print_graph == True:
        title_display = '<figcaption>'+ str(title)+'</figcaption>'
        display(HTML(title_display))
        plotly.offline.iplot(fig);
        
    return fig

# %%
fig = make_toggle_plot(x, variable_list, title = 'Graph with toggle buttons')
# Out:
# <figcaption>Graph with toggle buttons</figcaption>
# <div id="24e98729-6031-42e5-9b25-ca00a28ad1dc" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("24e98729-6031-42e5-9b25-ca00a28ad1dc", [{"marker": {"opacity": 0.5, "size": 10}, "mode": "markers", "name": "sepal_length", "visible": true, "x": [1.4, 1.4, 1.3, 1.5, 1.4, 1.7, 1.4, 1.5, 1.4, 1.5, 1.5, 1.6, 1.4, 1.1, 1.2, 1.5, 1.3, 1.4, 1.7, 1.5, 1.7, 1.5, 1.0, 1.7, 1.9, 1.6, 1.6, 1.5, 1.4, 1.6, 1.6, 1.5, 1.5, 1.4, 1.5, 1.2, 1.3, 1.4, 1.3, 1.5, 1.3, 1.3, 1.3, 1.6, 1.9, 1.4, 1.6, 1.4, 1.5, 1.4, 4.7, 4.5, 4.9, 4.0, 4.6, 4.5, 4.7, 3.3, 4.6, 3.9, 3.5, 4.2, 4.0, 4.7, 3.6, 4.4, 4.5, 4.1, 4.5, 3.9, 4.8, 4.0, 4.9, 4.7, 4.3, 4.4, 4.8, 5.
3, 3.0, 4.1, 6.0, 5.1, 5.9, 5.6, 5.8, 6.6, 4.5, 6.3, 5.8, 6.1, 5.1, 5.3, 5.5, 5.0, 5.1, 5.3, 5.5, 6.7, 6.9, 5.0, 5.7, 4.9, 6.7, 4.9, 5.7, 6.0, 4.8, 4.9, 5.6, 5.8, 6.1, 6.4, 5.6, 5.1, 5.6, 6.1, 5.6, 5.5, 4.8, 5.4, 5.6, 5.1, 5.1, 5.9, 5.7, 5.2, 5.0, 5.2, 5.4, 5.1], "y": [3.5, 3.0, 3.2, 3.1, 3.6, 3.9, 3.4, 3.4, 2.9, 3.1, 3.7, 3.4, 3.0, 3.0, 4.0, 4.4, 3.9, 3.5, 3.8, 3.8, 3.4, 3.7, 3.6, 3.3, 3.4, 3.0, 3.4, 3.5, 3.4, 3.2, 3.1, 3.4, 4.1, 4.2, 3.1, 3.2, 3.5, 3.6, 3.0, 3.4, 3.5, 2.3, 3.2, 3.5, 3.8, 3.0, 3.8, 3.2, 3.7, 3.3, 3.2, 3.2, 3.1, 2.3, 2.8, 2.8, 3.3, 2.4, 2.9, 2.7, 2.0, 3.0, 2.2, 2.9, 2.9, 3.1, 3.0, 2.7, 2.2, 2.5, 3.2, 2.8, 2.5, 2.8, 2.9, 3.0, 2.8, 3.0, 2.9, 2.6, 2.4, 2.4, 2.7, 2.7, 3.0, 3.4, 3.1, 2.3, 3.0, 2.5, 2.6, 3.0, 2.6, 2.3, 2.7, 3.0, 2.9, 2.9, 2.5, 2.8, 3.3, 2.7, 3.0, 2.9, 3.0, 3.0, 2.5, 2.9, 2.5, 3.6, 3.2, 2.7, 3.0, 2.5, 2.8, 3.2, 3.0, 3.8, 2.6, 2.2, 3.2, 2.8, 2.8, 2.7, 3.3, 3.2, 2.8, 3.0, 2.8, 3.0, 2.8, 3.8, 2.8, 2.8, 2.6, 3.0, 3.4, 3.1, 3.0, 3.1, 3.1, 3.1, 2.7, 3.2, 3.3, 3.0, 2.5, 3.0, 3.4, 3.0], "type": "scatter", "uid": "ab8b5817-2332-4043-be2d-d61b142e3592"}, {"marker": {"opacity": 0.5, "size": 10}, "mode": "markers", "name": "petal_length", "visible": false, "x": [1.4, 1.4, 1.3, 1.5, 1.4, 1.7, 1.4, 1.5, 1.4, 1.5, 1.5, 1.6, 1.4, 1.1, 1.2, 1.5, 1.3, 1.4, 1.7, 1.5, 1.7, 1.5, 1.0, 1.7, 1.9, 1.6, 1.6, 1.5, 1.4, 1.6, 1.6, 1.5, 1.5, 1.4, 1.5, 1.2, 1.3, 1.4, 1.3, 1.5, 1.3, ...

# %% [markdown]
# Hopefully this has shown how you can build up functions to achieve different types of graphs, and save you the pain of trying to edit things manually.

# %%
display(HTML('''
<hr> 
<div class = 'footnote'>
Contact gena.gibson@ricardo.com for suggestions <br>
Version last updated on 20 July 2019
</div>'''))
# Out:
# <hr>
# <div class = 'footnote'>
# Contact gena.gibson@ricardo.com for suggestions <br>
# Version last updated on 20 July 2019
# </div>
